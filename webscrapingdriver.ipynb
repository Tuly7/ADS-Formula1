# %%
# Set working directory
import os
cwd = os.getcwd()

# Warnings settings
import warnings
warnings.filterwarnings("ignore")

# %%
import io
from PIL import Image
import requests
import hashlib

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import pandas as pd
import seaborn as sns

print(tf.__version__)
# Out:
# 2.7.0

# %%
df_drivers = pd.read_csv('/Users/tuleyb/Desktop/ADS Projekt/f1db_csv/drivers.csv')
df_drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  1995-09-23
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
# ...

# %%
df_drivers.drop (
    labels= ["full name"],
    axis=1,
    inplace=True)

# %%
df_drivers
# Out:
#            driverRef  forename     surname         dob          fullname
# 0           hamilton     Lewis    Hamilton  1985-01-07     LewisHamilton
# 1           heidfeld      Nick    Heidfeld  1977-05-10      NickHeidfeld
# 2            rosberg      Nico     Rosberg  1985-06-27       NicoRosberg
# 3             alonso  Fernando      Alonso  1981-07-29    FernandoAlonso
# 4         kovalainen    Heikki  Kovalainen  1981-10-19  HeikkiKovalainen
# ..               ...       ...         ...         ...               ...
# 849           aitken      Jack      Aitken  1995-09-23        JackAitken
# 850          tsunoda      Yuki     Tsunoda  2000-05-11       YukiTsunoda
# 851          mazepin    Nikita     Mazepin  1999-03-02     NikitaMazepin
# 852  mick_schumacher      Mick  Schumacher  1999-03-22    MickSchumacher
# 853             zhou    Guanyu        Zhou  1999-05-30        GuanyuZhou
#
# [854 rows x 5 columns]

# %%
df_drivers["fullname"] = df_drivers["forename"] + df_drivers["surname"]
df_drivers
# Out:
#            driverRef  forename     surname         dob         full name  \
# 0           hamilton     Lewis    Hamilton  1985-01-07     LewisHamilton
# 1           heidfeld      Nick    Heidfeld  1977-05-10      NickHeidfeld
# 2            rosberg      Nico     Rosberg  1985-06-27       NicoRosberg
# 3             alonso  Fernando      Alonso  1981-07-29    FernandoAlonso
# 4         kovalainen    Heikki  Kovalainen  1981-10-19  HeikkiKovalainen
# ..               ...       ...         ...         ...               ...
# 849           aitken      Jack      Aitken  1995-09-23        JackAitken
# 850          tsunoda      Yuki     Tsunoda  2000-05-11       YukiTsunoda
# 851          mazepin    Nikita     Mazepin  1999-03-02     NikitaMazepin
# 852  mick_schumacher      Mick  Schumacher  1999-03-22    MickSchumacher
# 853             zhou    Guanyu        Zhou  1999-05-30        GuanyuZhou
#
#              fullname
# 0       LewisHamilton
# 1        NickHeidfeld
# ...

# %%
col_list = df_drivers.fullname.values.tolist()
print(col_list)
# Out:
# ['LewisHamilton', 'NickHeidfeld', 'NicoRosberg', 'FernandoAlonso', 'HeikkiKovalainen', 'KazukiNakajima', 'SébastienBourdais', 'KimiRäikkönen', 'RobertKubica', 'TimoGlock', 'TakumaSato', 'NelsonPiquet Jr.', 'FelipeMassa', 'DavidCoulthard', 'JarnoTrulli', 'AdrianSutil', 'MarkWebber', 'JensonButton', 'AnthonyDavidson', 'SebastianVettel', 'GiancarloFisichella', 'RubensBarrichello', 'RalfSchumacher', 'VitantonioLiuzzi', 'AlexanderWurz', 'ScottSpeed', 'ChristijanAlbers', 'MarkusWinkelhock', 'SakonYamamoto', 'MichaelSchumacher', 'JuanPablo Montoya', 'ChristianKlien', 'TiagoMonteiro', 'YujiIde', 'JacquesVilleneuve', 'FranckMontagny', 'Pedrode la Rosa', 'RobertDoornbos', 'NarainKarthikeyan', 'PatrickFriesacher', 'RicardoZonta', 'AntônioPizzonia', 'Cristianoda Matta', 'OlivierPanis', 'GiorgioPantano', 'GianmariaBruni', 'ZsoltBaumgartner', 'MarcGené', 'Heinz-HaraldFrentzen', 'JosVerstappen', 'JustinWilson', 'RalphFirman', 'NicolasKiesa', 'LucianoBurti', 'JeanAlesi', 'EddieIrvine', 'MikaHäkkinen
# ...

# %%
del col_list[20:850]
col_list
# Out:
# ['LewisHamilton',
#  'NickHeidfeld',
#  'NicoRosberg',
#  'FernandoAlonso',
#  'HeikkiKovalainen',
#  'KazukiNakajima',
#  'SébastienBourdais',
#  'KimiRäikkönen',
#  'RobertKubica',
#  'TimoGlock',
#  'TakumaSato',
#  'NelsonPiquet Jr.',
#  'FelipeMassa',
#  'DavidCoulthard',
#  'JarnoTrulli',
#  'AdrianSutil',
#  'MarkWebber',
#  'JensonButton',
#  'AnthonyDavidson',
#  'SebastianVettel']

# %%
def search_and_download(search_term:str,driver_path:str,target_path='./images',number_images=5):
    target_folder = os.path.join(target_path,'_'.join(search_term.lower().split(' ')))

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)
        
    for elem in res:
        persist_image(target_folder,elem)

# %%
for x in col_list:
    search_term= x
    search_and_download (
    search_term=search_term,
    driver_path='/Users/tuleyb/Desktop/ADS Projekt/chromedriver')
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 5 image links, done!
# SUCCESS - saved https://cdn-9.motorsport.com/images/mgl/0mb95oa2/s800/lewis-hamilton-mercedes-1.jpg - as ./images/lewishamilton/39701fd617.jpg
# SUCCESS - saved https://i.guim.co.uk/img/media/cabcfbdafc3b7e0854e07c35c35b18c199aa19a2/0_0_5130_3078/master/5130.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=e954cf8284c34c478581b7bae10d694e - as ./images/lewishamilton/ce28af6b80.jpg
# SUCCESS - saved https://thinkingheads.com/wp-content/uploads/2021/03/lewis-hamilton-f1-pilot-speaker-sports-thinking-heads.jpg - as ./images/lewishamilton/7968b215d8.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/1/18/Lewis_Hamilton_2016_Malaysia_2.jpg - as ./images/lewishamilton/1a0daba482.jpg
# SUCCESS - saved https://static.dw.com/image/50951286_303.jpg - as ./images/lewishamilton/f37760aa6d.jpg
# Found: 100 search results. Extracting links from 0:100
# Found: 5 image links, done!
# ...
