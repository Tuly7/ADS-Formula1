# %%
import pandas as pd

# %%
qualifying_df = pd.read_csv("qualifying.csv",index_col=False)
qualifying_df
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0             1      18         1              1      22         1  1:26.572
# 1             2      18         9              2       4         2  1:26.103
# 2             3      18         5              1      23         3  1:25.664
# 3             4      18        13              6       2         4  1:25.994
# 4             5      18         2              2       3         5  1:25.960
# ...         ...     ...       ...            ...     ...       ...       ...
# 9250       9308    1079        20            117       5        16  1:20.954
# 9251       9309    1079         4            214      14        17  1:21.043
# 9252       9310    1079       840            117      18        18  1:21.418
# 9253       9311    1079       848              3      23        19  1:21.645
# 9254       9312    1079       849              3       6        20  1:21.915
#
#             q2        q3
# ...

# %%
drivers_df = pd.read_csv("drivers.csv",index_col=False)
drivers_df
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  1995-09-23
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
# ...

# %%
driver_standings_df = pd.read_csv("driver_standings.csv",index_col=False)
driver_standings_df
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33534              71371    1079       807     0.0        20           20
# 33535              71372    1079       815    85.0         3            3
# 33536              71373    1079       830   110.0         1            1
# 33537              71374    1079       842     6.0        13           13
# 33538              71375    1079        20     4.0        14           14
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
races_df = pd.read_csv("races.csv",index_col=False)
races_df
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1074    1092  2022     18         22       Japanese Grand Prix  2022-10-09
# 1075    1093  2022     19         69  United States Grand Prix  2022-10-23
# 1076    1094  2022     20         32    Mexico City Grand Prix  2022-10-30
# 1077    1095  2022     21         18      Brazilian Grand Prix  2022-11-13
# 1078    1096  2022     22         24      Abu Dhabi Grand Prix  2022-11-20
#
# ...

# %%
results_df = pd.read_csv("results.csv",index_col=False)
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25515     25521    1079       849              3      6    19       16
# 25516     25522    1079       825            210     20     8       17
# 25517     25523    1079       848              3     23    18       18
# 25518     25524    1079       855             51     24    15       \N
# 25519     25525    1079       844              6     16     1       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
#Machine Learning: Logistic Regression um Probability des WM-Titels für jeden Fahrer vorherzusagen. --> DRIVER mit höchster Prob wird gemäss Modell WM Sieger.
#--> Inputfaktoren: Gewichtete Parameter (siehe unten 1-6)
# y-Achse = Probability (0-1) / x-Achse = weighted sum of input features (Gewichtete Parameter, x1 + x2 etc.)
#Welche Daten sind für die Prediction relevant? 
# 1) Starting Grid Position --> QF Ränge Durchschnitt pro Saison 
# 2) Alter (Erfahrung als Fahrer vs. irgendwann Peak erreicht und zu alt)
# 3) Fahrzeuge / Teams gewichten (z.B: RedBull höhere Wahrscheinlichkeit als Williams)
# 4) Budget (Welcher Constructor hat wie viel Geld? --> Viel Geld höhere Chance als wenig. Geld)
# 5) Marktwert Driver 
# 6) Hype auf social Media (Einfluss Anzahl Tweets pro Team pro Wochenende oder Season auf Schlussrangierung WM-Klassement)
# 7) Aktuelle Rangposition des DRIVERs --> aktuell beim Live Modell
# 8) WM Klassierung vergangene Jahre 
# Abhängige Variabel: Probability of Chance to Win the Championship pro DRRIVER 

#Wie werden die Parameter gewichtet? --> Analyse der letzen x Jahre auf Auswirkung der Parameter auf WM Titel.
# Wie werden die Daten ins Modell eingebaut --> Features erstellen x1, x2, etc. / Parameter. sind immer in Abhängigkeit 
#zum Ergebnis der Rangliste der einzelnen Rennen
# Gewichtung der Parameter werden auf Basis von historischen Daten gemacht --> 2016 - 2021
# Steps: 
# 1)Basisdataset erstellen --> CSV / Cleansing (bsp. Tabelle --> Name Driver, Rennergebnisse, Starting Grid, Alter Fahrer, Jahres Budget Team, Marktwert Driver, Aktuelle Rangposition des Drivers.  )
# 2)Features erstellen aus Dataset --> x1, x2, x3, 
# 3)Sklearn Logistic Regression Model einsetzen mit Features --> Trainings Daten 2016 - 2020 / Test 2021 / Live: aktuelle Daten
# 4)Docker Instanz
# 5)API checken
# 6)Verbdindung Model Prediction mit Scraping --> If Driver with highest Probability = Verstappen then print Picture of Verstappen
# 7)Bias und kritische Würdigung
# 8)Präsentation erstellen 
# 9)Video aufnehmen
